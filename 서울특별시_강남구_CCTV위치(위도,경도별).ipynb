# %% [markdown]
# <a href="https://colab.research.google.com/github/01chic/01.Crime/blob/master/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C_%EA%B0%95%EB%82%A8%EA%B5%AC_CCTV%EC%9C%84%EC%B9%98(%EC%9C%84%EB%8F%84%2C%EA%B2%BD%EB%8F%84%EB%B3%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ce6fae55-98f3-40bf-90eb-12fe9ec96019" name="files[]" multiple disabled />
#      <output id="result-ce6fae55-98f3-40bf-90eb-12fe9ec96019">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 서울특별시_강남구_CCTV_20181008.csv to 서울특별시_강남구_CCTV_20181008.csv

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("서울특별시_강남구_CCTV_20181008.csv",sep=",",encoding='euc-kr')

# %%
data.shape
# Out:
# (1837, 13)

# %%
data.columns
# Out:
# Index(['관리기관명', '소재지도로명주소', '소재지지번주소', '설치목적구분', '카메라대수', '카메라화소수', '촬영방면정보',
#        '보관일수', '설치년월', '관리기관전화번호', '위도', '경도', '데이터기준일자'],
#       dtype='object')

# %%
data.head()
# Out:
#         관리기관명                       소재지도로명주소  \
# 0  서울특별시 강남구청                            NaN
# 1  서울특별시 강남구청                            NaN
# 2  서울특별시 강남구청    서울특별시 강남구 선릉로 7 (개포동,주공아파트)
# 3  서울특별시 강남구청  서울특별시 강남구 언주로 110 (개포동,경남아파트)
# 4  서울특별시 강남구청        서울특별시 강남구 선릉로 103 (개포동)
#
#                                  소재지지번주소 설치목적구분  카메라대수  카메라화소수   촬영방면정보  보관일수  \
# 0                      서울특별시 강남구 세곡동 103     기타      4     300  360도전방면    30
# 1                      서울특별시 강남구 세곡동 103     기타      1     200  360도전방면    30
# 2  서울특별시 강남구 개포동 141-1 (구룡마을입구 교차로 지하보도)   생활방범      4     200  360도전방면    30
# 3      서울특별시 강남구 개포동 649 (경남1차A 2동 옆 정문)   생활방범      4     200  360도전방면    30
# 4             서울특별시 강남구 개포동 650 (구룡중 담장)   생활방범      4     200  360도전방면    30
#
#       설치년월      관리기관전화번호         위도          경도     데이터기준일자
# 0  2016-12  02-3423-6772  37.466587  127.108662  2018-10-08
# 1  2016-12  02-3423-6772  37.466584  127.108590  2018-10-08
# ...

# %%
data.plot(kind="scatter",x="경도",y="위도",alpha=1,s=data["카메라대수"],
          label="카메라대수",figsize=(15,10),c= "카메라대수", cmap = plt.get_cmap("jet"),colorbar=True)
plt.legend()
