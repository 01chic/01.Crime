# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
subway = pd.read_csv('get_subway.csv', thousands =',', encoding='utf-8')
subway.head()
# Out:
#       사용월  호선명 지하철역  유임승차인원  무임승차인원  유임하차인원  무임하차인원      작업일자
# 0  201809  1호선  동묘앞  180743  152019  200329  154759  20181003
# 1  201809  1호선  동대문  325486  127922  371065  132471  20181003
# 2  201809  중앙선   지평     946     772     921     709  20181003
# 3  201809  중앙선   중랑  119187   51206  110720   49482  20181003
# 4  201809  중앙선   원덕    7946    6607    7407    6310  20181003

# %%
import googlemaps

# %%
gmaps_key = "AIzaSyAX_9p1IL2yTblniH_YO3PmvXPv16evBGo"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
station_name = []
for name in subway['지하철역']:
    station_name.append(str(name[:]) + '역' )
    
station_name
# Out:
# ['동묘앞역',
#  '동대문역',
#  '지평역',
#  '중랑역',
#  '원덕역',
#  '운길산역',
#  '용문역',
#  '오빈역',
#  '양평역',
#  '양정역',
#  '양원역',
#  '양수역',
#  '아신역',
#  '신원역',
#  '상봉(시외버스터미널)역',
#  '망우역',
#  '도심역',
#  '도농역',
#  '덕소역',
#  '회기역',
#  '구리역',
#  '배방역',
#  '아산역',
#  '봉명역',
#  '온양온천역',
#  '신창(순천향대)역',
#  '쌍용(나사렛대)역',
#  '삼송역',
#  '백석역',
#  '원당역',
#  '원흥역',
#  '정발산역',
#  '주엽역',
#  '지축역',
#  '대화역',
#  '마두역',
#  '화정역',
#  '대곡역',
#  '삼양사거리역',
#  '정릉역',
#  '신설동역',
#  '솔샘역',
#  '솔밭공원역',
#  '성신여대입구(돈암)역',
#  '화계역',
#  '삼양역',
#  '북한산우이역',
#  '북한산보국문역',
#  '보문역',
#  '가오리역',
#  '4.19민주묘지역',
#  '신길온천역',
#  '초지역',
#  '중앙역',
#  '정왕역',
#  '오이도역',
#  '안산역',
#  '한대앞역',
#  '수리산역',
#  '상록수역',
#  '산본역',
#  '반월역',
#  '대야미역',
#  '고잔역',
#  '연수역',
#  '인하대역',
#  '인천논현역',
#  '인천역',
#  '월곶역',
#  '원인재역',
#  '호구포역',
#  '신포역',
#  '숭의역',
#  '송도역',
#  '소래포구역',
#  '달월역',
#  '남동인더스파크역',
#  '강남구청역',
#  '태평역',
#  '청명역',
#  '죽전역',
#  '정자역',
#  '이매역',
#  '오리역',
#  '영통역',
#  '야탑역',
#  '압구정로데오역',
#  '신갈역',
#  '수원시청역',
#  '수원역',
#  '수서역',
# ...

# %%
station_address = []
station_lat = []
station_lng = []

for name in station_name:
    tmp = gmaps.geocode(name, language='ko')
    station_address.append(tmp[0].get("formatted_address"))
    
    tmp_loc = tmp[0].get("geometry")

    station_lat.append(tmp_loc['location']['lat'])
    station_lng.append(tmp_loc['location']['lng'])
    
    print(name + '-->' + tmp[0].get("formatted_address"))
#구글맵에서 만들어둔 경찰서 이름을 이용해서 주소를 받아옴 - > 각 경찰서별 주소를 모두 얻어옴
# Out:
# 동묘앞역-->대한민국 서울특별시 숭인동 동묘앞역
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-e3bccbb8abbf> in <module>
#       5 for name in station_name:
#       6     tmp = gmaps.geocode(name, language='ko')
# ----> 7     station_address.append(tmp[0].get("formatted_address"))
#       8
#       9     tmp_loc = tmp[0].get("geometry")
#
# IndexError: list index out of range
